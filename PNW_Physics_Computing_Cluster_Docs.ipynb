# %% [markdown]
# <a href="https://colab.research.google.com/github/goodbyeskyharbor/pnw-cluster-documentation/blob/main/PNW_Physics_Computing_Cluster_Docs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Foreword
# PNW Physics Computing Cluster Official Documentation
#
# Authored by Joe Hudec(jhudec@pnw.edu)
#
# This documentation stands as the current state of the cluster and will record operating procedures, physical setup, and other crucial information to keeping the cluster operating optimal and organized for physics students to run their code on.

# %% [markdown]
# # Physical Structure
#
# This section dicusses the physical setup of the cluster and how each device communicates with the others and the internet.
#
# ## Device information
#
# This sub-section reflects the current device addressing and configuration as of 11/20/25.

# %%
import pandas as pd

pd.read_csv('cluster-computer-info.csv')
# Out:
#                       Computer Name        IP Number Service Tag  \
# 0         galileo.astrophys.pnw.edu     10.200.207.1     1L3W382
# 1           tycho.astrophys.pnw.edu     10.200.207.2     4CYFHL2
# 2          kepler.astrophys.pnw.edu     10.200.207.3     JP3XT52
# 3      copernicus.astrophys.pnw.edu     10.200.207.4     9P6XQ22
# 4        einstein.astrophys.pnw.edu     10.200.207.5     JP3LT52
# 5         hawking.astrophys.pnw.edu     10.200.207.6     JP3PT52
# 6          hubble.astrophys.pnw.edu     10.200.207.7     5H4GQ22
# 7         huygens.astrophys.pnw.edu     10.200.207.8     6QH08X2
# 8         messier.astrophys.pnw.edu     10.200.207.9     6QGZ7X2
# 9         penrose.astrophys.pnw.edu    10.200.207.10     2J0QQ22
# 10        ptolemy.astrophys.pnw.edu    10.200.207.11     BSG8JB2
# 11           guth.astrophys.pnw.edu    10.200.207.12     4CYQXK2
# 12  chandrasekhar.astrophys.pnw.edu    10.200.207.13     BSG6JB2
# ...

# %% [markdown]
# ## Addressing
